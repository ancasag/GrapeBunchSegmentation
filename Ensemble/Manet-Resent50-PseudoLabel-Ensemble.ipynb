td>
#       <td>00:36</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.237099</td>
#       <td>0.450106</td>
#       <td>0.891193</td>
#       <td>0.748238</td>
#       <td>0.834808</td>
#       <td>0.833577</td>
#       <td>0.838206</td>
#       <td>0.830569</td>
#       <td>00:35</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.242967</td>
#       <td>0.500806</td>
#       <td>0.900554</td>
#       <td>0.709890</td>
#       <td>0.819531</td>
#       <td>0.817911</td>
#       <td>0.822587</td>
#       <td>0.814858</td>
#       <td>00:35</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.230956</td>
#       <td>0.442191</td>
#       <td>0.889362</td>
#       <td>0.757462</td>
#       <td>0.838413</td>
#       <td>0.837124</td>
#       <td>0.842189</td>
#       <td>0.834392</td>
#       <td>00:36</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.237764</td>
#       <td>0.483288</td>
#       <td>0.899967</td>
#       <td>0.726314</td>
#       <td>0.826348</td>
#       <td>0.824246</td>
#       <td>0.829534</td>
#       <td>0.822044</td>
#       <td>00:35</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.237090</td>
#       <td>0.470005</td>
#       <td>0.898404</td>
#       <td>0.730891</td>
#       <td>0.827958</td>
#       <td>0.826611</td>
#       <td>0.831570</td>
#       <td>0.823973</td>
#       <td>00:36</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.234758</td>
#       <td>0.456504</td>
#       <td>0.891379</td>
#       <td>0.743336</td>
#       <td>0.833007</td>
#       <td>0.831995</td>
#       <td>0.836909</td>
#       <td>0.828747</td>
#       <td>00:36</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.4880278706550598.
# Better model found at epoch 1 with valid_loss value: 0.4661034941673279.
# Better model found at epoch 4 with valid_loss value: 0.45851966738700867.
# Better model found at epoch 6 with valid_loss value: 0.4542961120605469.
# Better model found at epoch 7 with valid_loss value: 0.4501055181026459.
# Better model found at epoch 9 with valid_loss value: 0.4421909749507904.
# No improvement since epoch 9: early stopping

# %%
learn.validate()
# Out:
# (#7) [0.4421909749507904,0.8893617987632751,0.7574618458747864,0.8384132385253906,0.837123692035675,0.8421887755393982,0.8343915939331055]

# %%
learn.show_results(figsize=(20,20))

# %%
aux=learn.model
aux=aux.cpu()

traced_cell=torch.jit.script(aux)
traced_cell.save("deeplab.pth")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-32-8ad6336e5121> in <module>
#       2 aux=aux.cpu()
#       3
# ----> 4 traced_cell=torch.jit.script(aux)
#       5 traced_cell.save("deeplab.pth")
#
# ~/.virtualenvs/segmentation/lib/python3.6/site-packages/torch/jit/_script.py in script(obj, optimize, _frames_up, _rcb)
#     896     if isinstance(obj, torch.nn.Module):
#     897         return torch.jit._recursive.create_script_module(
# --> 898             obj, torch.jit._recursive.infer_methods_to_compile
#     899         )
#     900
#
# ~/.virtualenvs/segmentation/lib/python3.6/site-packages/torch/jit/_recursive.py in create_script_module(nn_module, stubs_fn, share_types)
#     350     check_module_initialized(nn_module)
#     351     concrete_type = get_module_concrete_type(nn_module, share_types)
# --> 352     return create_script_module_impl(nn_module, concrete_type, stubs_fn)
#     353
#     354 def create_script_module_impl(nn_module, concrete_type, stubs_fn):
#
# ~/.virtualenvs/segmentation/lib/python3.6/site-packages/torch/jit/_recursive.py in create_script_module_impl(nn_module, concrete_type, stubs_fn)
#     404
#     405     # Actually create the ScriptModule, initializing it with the function we just defined
# --> 406     script_module = torch.jit.RecursiveScriptModule._construct(cpp_module, init_fn)
#     407
#     408     # Compile methods if necessary
#
# ~/.virtualenvs/segmentation/lib/python3.6/site-packages/torch/jit/_script.py in _construct(cpp_module, init_fn)
#     386             """
#     387             script_module = RecursiveScriptModule(cpp_module)
# --> 388             init_fn(script_module)
#     389
#     390             # Finalize the ScriptModule: replace the nn.Module state with our
#
# ~/.virtualenvs/segmentation/lib/python3.6/site-packages/torch/jit/_recursive.py in init_fn(script_module)
#     386             else:
#     387                 # always reuse the provided stubs_fn to infer the methods to compile
# --> 388                 scripted = create_script_module_impl(orig_value, sub_concrete_type, stubs_fn)
#     389
#     390             cpp_module.setattr(name, scripted)
#
# ~/.virtualenvs/segmentation/lib/python3.6/site-packages/torch/jit/_recursive.py in create_script_module_impl(nn_module, concrete_type, stubs_fn)
#     408     # Compile methods if necessary
#     409     if concrete_type not in concrete_type_store.methods_compiled:
# --> 410         create_methods_and_properties_from_stubs(concrete_type, method_stubs, property_stubs)
#     411         torch._C._run_emit_module_hook(cpp_module)
#     412         concrete_type_store.methods_compiled.add(concrete_type)
#
# ~/.virtualenvs/segmentation/lib/python3.6/site-packages/torch/jit/_recursive.py in create_methods_and_properties_from_stubs(concrete_type, method_stubs, property_stubs)
#     302     property_rcbs = [p.resolution_callback for p in property_stubs]
#     303
# --> 304     concrete_type._create_methods_and_properties(property_defs, property_rcbs, method_defs, method_rcbs, method_defaults)
#     305
#     306
#
# RuntimeError:
# tuple slice indices must be integer constants:
#   File "/home/jonathan/.virtualenvs/segmentation/lib/python3.6/site-packages/segmentation_models_pytorch/encoders/_base.py", line 18
#     def out_channels(self):
#         """Return channels dimensions for each tensor of forward output of encoder"""
#         return self._out_channels[: self._depth + 1]
#                ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ <--- HERE

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu") 

# HRNet

model = torch.jit.load("deeplab.pth")
model = model.cpu()
model.eval()

# %%
import torchvision.transforms as transforms
def transform_image(image):
    my_transforms = transforms.Compose([transforms.ToTensor(),
                                        transforms.Normalize(
                                            [0.485, 0.456, 0.406],
                                            [0.229, 0.224, 0.225])])
    image_aux = image
    return my_transforms(image_aux).unsqueeze(0).to(device)

# %%
image = Image.open('dataset/Images/test/color_154.jpg')

# %%
image = transforms.Resize((480,640))(image)
tensor = transform_image(image=image)

# %%
model.to(device)
with torch.no_grad():
    outputs = model(tensor)

outputs = torch.argmax(outputs,1)

# %%
mask = np.array(outputs.cpu())

# %%
mask[mask==4]=255
mask[mask==1]=150
mask[mask==3]=76
mask[mask==2]=29

# %%
mask=np.reshape(mask,(480,640))

# %%
maskShow = Image.fromarray(mask.astype('uint8'))
maskShow

# %%
maskrgb = maskShow.convert('RGB')
maskrgb = np.array(maskrgb)
maskrgb[(maskrgb==[150,150,150]).all(axis=2)]=[0,255,0]
maskrgb[(maskrgb==[76,76,76]).all(axis=2)]=[255,0,0]
maskrgb[(maskrgb==[29,29,29]).all(axis=2)]=[0,0,255]

# %%
maskRGBShow = Image.fromarray(maskrgb.astype('uint8'))
maskRGBShow

# %%
maskRGBShow.save('deeplab_pred_155.jpg')
